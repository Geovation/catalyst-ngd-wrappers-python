# %%
import requests as r
import re
import os
import logging
from datetime import datetime, timedelta
from dotenv import load_dotenv
from shapely import from_wkt
from shapely.geometry import Point, LineString, Polygon, MultiPolygon

# %%
load_dotenv()
# Out:
# True

# %%
def generic_request(url: str, headers: dict = {}, access_token: str = None, **kwargs) -> dict:

    if access_token:
        headers['Authorization'] = f"Bearer {access_token}"
    response = r.get(url, headers=headers, **kwargs)
    json_response = response.json()
    if response.status_code >= 400:
        raise Exception(json_response)

    return json_response

# %%
def get_access_token(client_id: str, client_secret: str) -> str:
    '''
    Supplies a temporary access token for of the OS NGD API
    Times out after 5 minutes
    Takes the project client_id and client_secret as input
    '''

    url = "https://api.os.uk/oauth2/token/v1"

    data = {
        "grant_type": "client_credentials"
    }

    response = r.post(
        url, 
        auth=(client_id, client_secret),
        data=data
    )

    json_response = response.json()
    if response.status_code >= 400:
        raise Exception(json_response)
    token = json_response["access_token"]

    return token

# %%
def OAauth2_manager(func: callable):

    def wrapper(*args, **kwargs):

        kwargs_ = kwargs.copy()

        try:
            access_token = os.environ.get('ACCESS_TOKEN')
            kwargs_['access_token'] = access_token
            return func(*args, **kwargs_)
        except Exception:
            client_id = os.environ.get('CLIENT_ID')
            client_secret = os.environ.get('CLIENT_SECRET')
            access_token = get_access_token(
                client_id=client_id,
                client_secret=client_secret
            )
            os.environ['ACCESS_TOKEN'] = access_token
            kwargs_['access_token'] = access_token
            return func(*args, **kwargs_)

    wrapper.__name__ = func.__name__ + '+OAuth2_manager'
    funcname = func.__name__
    wrapper.__doc__ = f"""
    An extension of the function {funcname} handling OAauth2 authorisation.
    IMPORTANT:
        CLIENT_ID and CLIENT_SECRET must be set as environment variables for this extension to work.
        This can be done using a .env file and load_dotenv()
    Docs for OAuth2 with Ordnance Survey data can be found at https://osdatahub.os.uk/docs/oauth2/overview
    The function automatically ensures a valid temporary access token (expiring after 5 minutes) is being used. This will either be an existing valid token, or a newly called one.

    ____________________________________________________
    Docs for {funcname}:
        {func.__doc__}
    """
    return wrapper

# %%
def wkt_to_spatial_filter(wkt, predicate='INTERSECTS'):
    '''Constructs a full spatial filter in conformance with the OGC API - Features standard from well-known-text (wkt)
    Currently, only 'Simple CQL' conformance is supported, therefore INTERSECTS is the only supported spatial predicate: https://portal.ogc.org/files/96288#rc_simple-cql'''
    return f'({predicate}(geometry,{wkt}))'

# %%
def construct_bbox_filter(
        bbox_tuple: tuple[float | int] | str = None,
        xmin: float | int = None,
        ymin: float | int = None,
        xmax: float | int = None,
        ymax: float | int = None
):
    if bbox_tuple:
        return str(bbox_tuple)[1:-1].replace(' ','')
    list_ = list()
    for z in [xmin, ymin, xmax, ymax]:
        if z == None:
            raise AttributeError('You must provide either bbox_tuple or all of [xmin, ymin, xmax, ymax]')
        list_.append(str(z))
    if xmin > xmax:
        raise ValueError('xmax must be greater than xmin')
    if ymin > ymax:
        raise ValueError('ymax must be greater than ymin')
    return ','.join(list_)

# %%
def construct_query_params(**params) -> str:
    '''
    Constructs a query string from a dictionary of key-value pairs.
    Refer to https://osdatahub.os.uk/docs/ofa/technicalSpecification for details about query parameters.
    The options are:
        - bbox
        - bbox-crs
        - crs
        - datetime
        - filter
        - filter-crs (can be supplied as a full http ref, or an integer)
        - filter-lang
        - limit
        - offset
    '''
    for p in ['crs', 'bbox-crs', 'filter-crs']:
        crs = params.get(p)
        if type(crs) == int:
            params[p] = f'http://www.opengis.net/def/crs/EPSG/0/{crs}'
    params_list = [f'{k}={v}' for k, v in params.items()]
    return '?' + '&'.join(params_list)

# %%
def construct_filter_param(**params):
    '''Constructs a set of key=value parameters into a filter string for an API query'''
    for k, v in params.items():
        if type(v) == str:
            params[k] = f"'{v}'"
    filter_list = [f"({k}={v})" for k, v in params.items()]
    return 'and'.join(filter_list)

# %%
def ngd_items_request(
    collection: str,
    query_params: dict = {},
    filter_params: dict = {},
    wkt = None,
    headers: dict = {},
    access_token: str = None,
    verbose: bool = False,
    **kwargs
) -> dict:
    """
    Calls items from the OS NGD API - Features
        - https://osdatahub.os.uk/docs/wfs/overview
        - https://docs.os.uk/osngd/accessing-os-ngd/access-the-os-ngd-api/os-ngd-api-features
    Parameters:
        collection (str) - the feature collection to call from. Feature collection names and details can be found at https://api.os.uk/features/ngd/ofa/v1/collections/
        query_params (dict, optional) - parameters to pass to the query as query parameters, supplied in a dictionary. Supported parameters are: bbox, bbox-crs, crs, datetime, filter, filter-crs, filter-lang, limit, offset
        filter_params (dict, optional) - OS NGD attribute filters to pass to the query within the 'filter' query_param. The can be used instead of or in addition to manually setting the filter in query_params.
            The key-value pairs will appended using the EQUAL TO [ = ] comparator. Any other CQL Operator comparisons must be set manually in query_params.
            Queryable attributes can be found in OS NGD codelists documentation https://docs.os.uk/osngd/code-lists/code-lists-overview, or by inserting the relevant collectionId into the https://api.os.uk/features/ngd/ofa/v1/collections/{{collectionId}}/queryables endpoint.
        wkt (string or shapely geometry object) - A means of searching a geometry for features. The search area(s) must be supplied in wkt, either in a string or as a Shapely geometry object.
            The function automatically composes the full INTERSECTS filter and adds it to the 'filter' query parameter.
            Make sure that 'filter-crs' is set to the appropriate value.
        headers (dict, optional) - Headers to pass to the query. These can include bearer-token authentication.
        access_token (str) - An access token, which will be added as bearer token to the headers.
        **kwargs: other generic parameters to be passed to the requests.get()

    Returns the features as a geojson, as per the OS NGD API.
    """

    query_params_ = query_params.copy()
    filter_params_ = filter_params.copy()
    headers_ = headers.copy()

    if filter_params_:
        filters = construct_filter_param(**filter_params_)
        current_filters = query_params_.get('filter')
        query_params_['filter'] = f'({current_filters})and{filters}' if current_filters else filters

    if wkt:
        spatial_filter = wkt_to_spatial_filter(wkt)
        current_filters = query_params_.get('filter')
        query_params_['filter'] = f'({current_filters})and{spatial_filter}' if current_filters else spatial_filter

    query_params_string = construct_query_params(**query_params_)
    url = f'https://api.os.uk/features/ngd/ofa/v1/collections/{collection}/items/{query_params_string}'
    if verbose:
        print(url)
    if access_token:
        headers_['Authorization'] = f"Bearer {access_token}"
    response = r.get(url, headers=headers_, **kwargs)
    json_response = response.json()

    if response.status_code >= 400:
        raise Exception(json_response)

    return json_response

# %%
def feature_limit_extension(func: callable):

    def wrapper(
        *args,
        request_limit: int = 50,
        feature_limit: int = None,
        query_params: dict = {},
        **kwargs
    ):

        query_params_ = query_params.copy()

        if 'offset' in query_params_:
            raise AttributeError('offset is not a valid argument for functions using this decorator.')

        items = list()

        batch_count, final_batchsize = divmod(feature_limit, 100) if feature_limit else (None, None)
        request_count = 0
        offset = 0

        if not(feature_limit) and not(request_limit):
            raise AttributeError('At least one of feature_limit or request_limit must be provided to prevent indefinitely numerous requests and high costs. However, there is no upper limit to these values.')

        while (request_count != request_limit) and (not(feature_limit) or offset < feature_limit):

            if request_count == batch_count:
                print('final batch of size', final_batchsize)
                query_params_['limit'] = final_batchsize
            query_params_['offset'] = offset

            json_response = func(*args, query_params=query_params_, **kwargs)
            request_count += 1
            items += json_response['features']

            if not [link for link in json_response['links'] if link['rel'] == 'next']:
                break
            
            offset += 100

        geojson = {
            "type": "FeatureCollection",
            "numberOfRequests": request_count,
            "totalNumberReturned": len(items),
            "timeStamp": datetime.now().isoformat(),
            "collection": kwargs.get('collection'),
            "source": "Compiled from code by Geovation from Ordnance Survey",
            "features": items
        }
        return geojson

    wrapper.__name__ = func.__name__ + '+feature_limit_extension'
    funcname = func.__name__
    wrapper.__doc__ = f"""
    This is an extension the {funcname} function, which returns OS NGD features. It serves to extend the maximum number of features returned above the default maximum 100 by looping through multiple requests.
    It takes the following arguments:
    - collection: The name of the collection to be queried.
    - request_limit: The maximum number of calls to be made to {funcname}. Default is 50.
    - feature_limit: The maximum number of features to be returned. Default is None.
    - query_params: A dictionary of query parameters to be passed to the function. Default is an empty dictionary.
    To prevent indefinite requests and high costs, at least one of feature_limit or request_limit must be provided, although there is no limit to the upper value these can be.
    It will make multiple requests to the function to compile all features from the specified collection, returning a dictionary with the features and metadata.

    ____________________________________________________
    Docs for {funcname}:
        {func.__doc__}
    """
    return wrapper

# %%
def multigeometry_search_extension(func: callable):

    def wrapper(*args, wkt: str, **kwargs):

        full_geom = from_wkt(wkt) if type(wkt) == str else wkt
        search_areas = list()

        is_single_geom = type(full_geom) in [Point, LineString, Polygon]
        partial_geoms = [full_geom] if is_single_geom else full_geom.geoms

        for search_area, geom in enumerate(partial_geoms):
            json_response = func(*args, wkt=geom, **kwargs)
            json_response['searchAreaNumber'] = search_area
            search_areas.append(json_response)

        geojson = {
            "type": "FeatureCollection",
            "searchAreas": search_areas
        }

        return geojson

    wrapper.__name__ = func.__name__ + '+multigeometry_search_extension'
    funcname = func.__name__
    wrapper.__doc__ = f"""
    An alternative means of returning OS NGD features for a search area which is a Multi-Geometry (MultiPoint, MultiLinestring, or MultiPolygon), which will in some cases improve speed, performance, and prevent the call from timing out.
    Extends to {funcname} function.
    Each component shape of the multi-geometry will be searched in turn using the {funcname} function.
    The results are returned in a quasi-GeoJSON format, with features returned under 'searchAreas' in a list, where each item is a json object of results from one search area.
    The search areas are labelled numerically, with the number stored under 'searchAreaNumber'.
    NOTE: If a limit is supplied for the maximum number of features to be returned or requests to be made, this will apply to each search area individually, not to the overall number of results.

    ____________________________________________________
    Docs for {funcname}:
        {func.__doc__}
    """
    return wrapper

# %%
def multiple_collections_extension(func: callable) -> dict:

    def wrapper(collections: list[str], *args, **kwargs):

        results = dict()
        for c in collections:
            json_response = func(c, *args, **kwargs)
            results[c] = json_response
        return results
    
    wrapper.__name__ = func.__name__ + '+multiple_collections_extension'
    funcname = func.__name__
    wrapper.__doc__ = f"""
    Extents the {funcname} function to handle multiple collections.
    Takes a list of collection names as input, alongside any other parameters which are passed to {funcname}.
    The function {funcname} will be run for each collection in turn, with the results returned in a dictionary mapping the collection names to the results.
    NOTE: If a limit is supplied for the maximum number of features to be returned or requests to be made, this will apply to each collection individually, not to the overall number of results.

    ____________________________________________________
    Docs for {funcname}:
        {func.__doc__}
    """
    return wrapper

# %%
def get_latest_collection_versions(flag_recent_updates: bool = True, recent_update_days: int = 31) -> tuple[dict[str: str], list[str]]:
    '''
    Returns the latest collection versions of each NGD collection.
    Feature collections follow the following naming convention: theme-collection-featuretype-version (eg. bld-fts-buildingline-2)
    The output of this function maps base feature collection names (theme-collection-featuretype) to the full name, including the latest version.
    This can be used to ensure that software is always using the latest version of a feature collection.
    More details on feature collection naming can be found at https://docs.os.uk/osngd/accessing-os-ngd/access-the-os-ngd-api/os-ngd-api-features/what-data-is-available
    '''

    response = r.get('https://api.os.uk/features/ngd/ofa/v1/collections/')
    collections_data = response.json()['collections']
    collections_list = [collection['id'] for collection in collections_data]
    collection_base_names = set([re.sub(r'-\d+$', '', c) for c in collections_list])
    output_lookup = dict()

    for base_name in collection_base_names:
        all_versions = [c for c in collections_list if c.startswith(base_name)]
        latest_version = max(all_versions, key=lambda c: int(c.split('-')[-1]))
        output_lookup[base_name] = latest_version

    recent_collections = None
    if flag_recent_updates:
        time_format = r'%Y-%m-%dT%H:%M:%SZ'
        recent_update_cutoff = datetime.now() - timedelta(days=recent_update_days)
        latest_versions_data = [c for c in collections_data if c['id'] in output_lookup.values()]
        recent_collections = list()
        for collection_data in latest_versions_data:
            version_startdate = collection_data['extent']['temporal']['interval'][0][0]
            time_obj = datetime.strptime(version_startdate, time_format)
            if time_obj > recent_update_cutoff:
                collection = collection_data['id']
                recent_collections.append(collection)
                logging.warning(f'{collection} is a recent version/update from the last {recent_update_days} days.')

    return output_lookup, recent_collections

# %%
def get_single_latest_collection(collection: str, **kwargs) -> str:
    '''
    Returns the latest collection of a given collection base.
    Input must be in the format theme-collection-featuretype (eg. bld-fts-buildingline)
    Output will complete the full name of the feature collection by appending the latest version number (eg. bld-fts-buildingline-2)
    More details on feature collection naming can be found at https://docs.os.uk/osngd/accessing-os-ngd/access-the-os-ngd-api/os-ngd-api-features/what-data-is-available
    '''
    latest_collections = get_latest_collection_versions(**kwargs)
    latest_collection = latest_collections[collection]
    return latest_collection

# %%
def comprehensive_enum_search(search_vals: str | list):

    if type(search_vals) == str:
        search_vals = [search_vals]
    search_vals = [sv.upper() for sv in search_vals]

    latest_versions = get_latest_collection_versions()
    latest_versions_list = list(latest_versions[0].values())

    output = dict()

    for collection in latest_versions_list:

        queryables = r.get(f'https://api.os.uk/features/ngd/ofa/v1/collections/{collection}/queryables').json()
        properties = queryables['properties']

        for attribute, data in properties.items():

            type_ = data['type'][0]
            if type_ == 'string':
                enum = data.get('enum')
                if not(enum):
                    continue
                matches = list()
                for sv in search_vals:
                    matches += [val for val in enum if sv in val.upper()]
                if matches:
                    output[collection] = output.get(collection, {})
                    output[collection][attribute] = matches

            elif type_ == 'array':
                items = data.get('items')
                if not(items):
                    continue
                enum = items.get('enum')
                if not(enum):
                    continue
                matches = list()
                for sv in search_vals:
                    matches += [val for val in enum if sv in val.upper()]
                if matches:
                    output[collection] = output.get(collection, {})
                    output[collection][attribute] = {'array':matches}

    return output

# %%
pilons = comprehensive_enum_search(['electricity','power','substation'])

# %%
pilons
# Out:
# {'trn-fts-roadtrackorpath-3': {'oslandusetierb': {'array': ['Electricity Distribution']}},
#  'bld-fts-buildingpart-2': {'oslandusetierb': {'array': ['Electricity Distribution']}},
#  'str-fts-structure-3': {'description': ['Electricity Metal Monopole',
#    'Electricity Pylon'],
#   'oslandusetierb': {'array': ['Electricity Distribution']}},
#  'str-fts-structureline-1': {'description': ['Electricity Transmission Lines']},
#  'lus-fts-site-2': {'description': ['Electricity Distribution Site',
#    'Electricity Storage Site',
#    'Electricity Sub Station',
#    'Biogas Power Station',
#    'Hydroelectric Power Generating',
#    'Power Station',
#    'Solar Power Site',
#    'Tidal Power Station'],
#   'oslandusetierb': {'array': ['Electricity Distribution']}},
#  'wtr-fts-water-3': {'oslandusetierb': {'array': ['Electricity Distribution']}},
#  'bld-fts-building-3': {'description': ['Electricity Distribution Facility',
#    'Electricity Storage Facility',
#    'Electricity Sub Station',
#    'Biogas Power Station',
#    'Hydroelectric Power Generating',
#    'Power Station',
#    'Solar Power Facility',
#    'Tidal Power Station']},
#  'lnd-fts-land-3': {'oslandusetierb': {'array': ['Electricity Distribution']}},
#  'trn-fts-rail-3': {'oslandusetierb': {'array': ['Electricity Distribution']}},
#  'str-fts-structurepoint-1': {'description': ['Electricity Sub Station',
#    'Electricity Support Pole',
#    'Electricity Support Poles']}}

# %%
from shapely.geometry import LineString, GeometryCollection

# %%
x=Polygon({(400000,400000), (400050,400000), (400050,400050), (400000,40050)})
y=Polygon({(500000,500000), (500050,500000), (500050,500050), (500000,50050)})

# %%
l = LineString([(399990,399990),(399970,399970)])

# %%
type(l) == LineString
# Out:
# True

# %%
geomcollect = GeometryCollection([x,l])

# %%
z=MultiPolygon([x,y])

# %% [markdown]
# # Example Ways of Building Custom APIs by Combining Wrappers

# %% [markdown]
# #### All possible combos with OAuth2

# %%
items_auth = OAauth2_manager(ngd_items_request)
items_auth_limit = feature_limit_extension(items_auth)
items_auth_limit_geom = multigeometry_search_extension(items_auth_limit)
items_auth_limit_geom_col = multiple_collections_extension(items_auth_limit_geom)

items_auth_geom = multigeometry_search_extension(items_auth)
items_auth_geom_col = multiple_collections_extension(items_auth_geom)

items_auth_limit_col = multiple_collections_extension(items_auth_limit)

items_auth_col = multiple_collections_extension(items_auth)

# %%
get_latest_collection_versions()
# Out:
# ({'trn-rami-specialdesignationpoint': 'trn-rami-specialdesignationpoint-1',
#   'trn-ntwk-pavementlink': 'trn-ntwk-pavementlink-1',
#   'trn-ntwk-connectingnode': 'trn-ntwk-connectingnode-1',
#   'bld-fts-buildingline': 'bld-fts-buildingline-1',
#   'gnm-fts-namedroadjunction': 'gnm-fts-namedroadjunction-1',
#   'trn-ntwk-path': 'trn-ntwk-path-1',
#   'lnd-fts-landform': 'lnd-fts-landform-1',
#   'lnd-fts-landformline': 'lnd-fts-landformline-1',
#   'lus-fts-siteaccesslocation': 'lus-fts-siteaccesslocation-1',
#   'trn-ntwk-roadnode': 'trn-ntwk-roadnode-1',
#   'trn-fts-cartographicraildetail': 'trn-fts-cartographicraildetail-1',
#   'str-fts-compoundstructure': 'str-fts-compoundstructure-2',
#   'trn-ntwk-pathlink': 'trn-ntwk-pathlink-1',
#   'lnd-fts-landpoint': 'lnd-fts-landpoint-1',
#   'trn-ntwk-pathnode': 'trn-ntwk-pathnode-1',
#   'trn-fts-roadtrackorpath': 'trn-fts-roadtrackorpath-3',
#   'trn-rami-restriction': 'trn-rami-restriction-1',
#   'bld-fts-buildingpart': 'bld-fts-buildingpart-2',
#   'str-fts-fieldboundary': 'str-fts-fieldboundary-1',
#   'wtr-ntwk-waterlinkset': 'wtr-ntwk-waterlinkset-1',
#   'trn-rami-averageandindicativespeed': 'trn-rami-averageandindicativespeed-1',
#   'str-fts-structure': 'str-fts-structure-3',
#   'trn-rami-maintenancepoint': 'trn-rami-maintenancepoint-1',
#   'wtr-ntwk-waterlink': 'wtr-ntwk-waterlink-1',
#   'trn-ntwk-roadlink': 'trn-ntwk-roadlink-3',
#   'str-fts-structureline': 'str-fts-structureline-1',
#   'trn-rami-routinghazard': 'trn-rami-routinghazard-1',
#   'gnm-fts-namedarea': 'gnm-fts-namedarea-1',
#   'trn-rami-reinstatementarea': 'trn-rami-reinstatementarea-1',
#   'trn-rami-specialdesignationarea': 'trn-rami-specialdesignationarea-1',
#   'trn-fts-roadline': 'trn-fts-roadline-1',
#   'lus-fts-site': 'lus-fts-site-2',
#   'wtr-fts-tidalboundary': 'wtr-fts-tidalboundary-1',
#   'trn-rami-reinstatementpoint': 'trn-rami-reinstatementpoint-1',
#   'trn-ntwk-railwaynode': 'trn-ntwk-railwaynode-1',
#   'trn-rami-maintenancearea': 'trn-rami-maintenancearea-1',
#   'trn-rami-routingstructure': 'trn-rami-routingstructure-1',
#   'trn-rami-reinstatementline': 'trn-rami-reinstatementline-1',
#   'gnm-fts-namedpoint': 'gnm-fts-namedpoint-1',
#   'trn-ntwk-railwaylinkset': 'trn-ntwk-railwaylinkset-1',
#   'wtr-fts-intertidalline': 'wtr-fts-intertidalline-1',
#   'wtr-fts-water': 'wtr-fts-water-3',
#   'wtr-ntwk-waternode': 'wtr-ntwk-waternode-1',
#   'lnd-fts-landformpoint': 'lnd-fts-landformpoint-1',
#   'bld-fts-building': 'bld-fts-building-3',
#   'trn-rami-specialdesignationline': 'trn-rami-specialdesignationline-1',
#   'trn-rami-maintenanceline': 'trn-rami-maintenanceline-1',
#   'wtr-fts-waterpoint': 'wtr-fts-waterpoint-1',
#   'trn-ntwk-road': 'trn-ntwk-roadlink-3',
#   'trn-rami-highwaydedication': 'trn-rami-highwaydedication-1',
#   'trn-ntwk-street': 'trn-ntwk-street-1',
#   'lus-fts-siteroutingpoint': 'lus-fts-siteroutingpoint-1',
#   'trn-ntwk-connectinglink': 'trn-ntwk-connectinglink-1',
#   'trn-ntwk-ferryterminal': 'trn-ntwk-ferryterminal-1',
#   'trn-ntwk-railwaylink': 'trn-ntwk-railwaylink-1',
#   'trn-ntwk-roadjunction': 'trn-ntwk-roadjunction-1',
#   'lnd-fts-land': 'lnd-fts-land-3',
#   'trn-ntwk-ferrylink': 'trn-ntwk-ferrylink-1',
#   'trn-fts-rail': 'trn-fts-rail-3',
#   'str-fts-structurepoint': 'str-fts-structurepoint-1',
#   'trn-ntwk-tramonroad': 'trn-ntwk-tramonroad-1',
#   'trn-ntwk-ferrynode': 'trn-ntwk-ferrynode-1'},
#  [])

# %%
items_auth_limit(
    collection='lus-fts-site-2',
    query_params={
        'bbox':construct_bbox_filter((400000,400000,405000,405000)),
        'bbox-crs':27700,
        'filter':"oslandusetierb ACONTAINS ['Electricity Distribution']"
    },
    verbose=True
)
# Out:
# https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-site-2/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&filter=oslandusetierb ACONTAINS ['Electricity Distribution']&offset=0
# https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-site-2/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&filter=oslandusetierb ACONTAINS ['Electricity Distribution']&offset=0
# {'type': 'FeatureCollection',
#  'numberOfRequests': 1,
#  'totalNumberReturned': 2,
#  'timeStamp': '2025-01-02T16:57:04.279219',
#  'collection': 'lus-fts-site-2',
#  'source': 'Compiled from code by Geovation from Ordnance Survey',
#  'features': [{'id': 'c583336b-cf3a-4902-b33a-19b830815337',
#    'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-1.9964562, 53.5311357],
#        [-1.9964758, 53.5310871],
#        [-1.9964155, 53.5310781],
#        [-1.9963973, 53.5311267],
#        [-1.9964562, 53.5311357]]]]},
#    'properties': {'osid': 'c583336b-cf3a-4902-b33a-19b830815337',
#     'toid': None,
#     'theme': 'Land Use',
#     'status': None,
#     'nlud_code': 'U061',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'description': 'Electricity Sub Station',
#     'matcheduprn': 10024991830,
#     'stakeholder': None,
#     'versiondate': '2024-09-06',
#     'mainbuildingid': None,
#     'name1_language': None,
#     'name2_language': None,
#     'oslandusetiera': 'Utility Or Environmental Protection',
#     'oslandusetierb': ['Electricity Distribution'],
#     'extentdefinition': 'Manually Defined Complete',
#     'geometry_area_m2': 22.58,
#     'name1_updatedate': None,
#     'name2_updatedate': None,
#     'status_updatedate': '2005-10-03',
#     'addresscount_other': 0,
#     'addresscount_total': 1,
#     'matcheduprn_method': 'Matched Using Single Address',
#     'name1_evidencedate': None,
#     'name2_evidencedate': None,
#     'geometry_updatedate': '2023-05-18',
#     'oslanduse_updatedate': '2005-10-03',
#     'geometry_evidencedate': '2023-05-18',
#     'nlud_groupdescription': 'Energy production and distribution',
#     'nlud_orderdescription': 'UTILITIES AND INFRASTRUCTURE',
#     'description_updatedate': '2005-10-03',
#     'geometry_capturemethod': 'Desk-Based',
#     'oslanduse_evidencedate': '2005-10-03',
#     'sitetoaddressreference': [{'uprn': 10024991830,
#       'siteid': 'c583336b-cf3a-4902-b33a-19b830815337',
#       'siteversiondate': '2024-09-06',
#       'relationshiptype': 'Same As'}],
#     'versionavailabletodate': None,
#     'addresscount_commercial': 1,
#     'oslanduse_capturemethod': 'Automated Process',
#     'addresscount_residential': 0,
#     'description_evidencedate': '2005-10-03',
#     'versionavailablefromdate': '2024-09-07T00:00:00Z',
#     'description_capturemethod': 'Automated Process',
#     'address_classificationcode': 'CU',
#     'address_primarydescription': 'Commercial',
#     'address_classificationsource': 'Matched UPRN',
#     'address_secondarydescription': 'Utility',
#     'address_classificationcorrelation': 'Good'}},
#   {'id': 'f31855a6-30f1-452d-ba13-35298b3c712f',
#    'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-1.9975467, 53.5326724],
#        [-1.9975409, 53.5326767],
#        [-1.9975244, 53.5327243],
#        [-1.9975817, 53.5327315],
#        [-1.9975998, 53.5327126],
#        [-1.9976013, 53.5327018],
#        [-1.9976069, 53.5326724],
#        [-1.9976073, 53.5326704],
#        [-1.9975545, 53.5326668],
#        [-1.9975467, 53.5326724]]]]},
#    'properties': {'osid': 'f31855a6-30f1-452d-ba13-35298b3c712f',
#     'toid': None,
#     'theme': 'Land Use',
#     'status': None,
#     'nlud_code': 'U061',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'description': 'Electricity Sub Station',
#     'matcheduprn': 10024998068,
#     'stakeholder': None,
#     'versiondate': '2024-09-06',
#     'mainbuildingid': '15144597-2b91-426e-9fab-71d5a0bd6831',
#     'name1_language': None,
#     'name2_language': None,
#     'oslandusetiera': 'Utility Or Environmental Protection',
#     'oslandusetierb': ['Electricity Distribution'],
#     'extentdefinition': 'Manually Defined Complete',
#     'geometry_area_m2': 29.206,
#     'name1_updatedate': None,
#     'name2_updatedate': None,
#     'status_updatedate': '2006-01-05',
#     'addresscount_other': 0,
#     'addresscount_total': 1,
#     'matcheduprn_method': 'Matched Using Single Address',
#     'name1_evidencedate': None,
#     'name2_evidencedate': None,
#     'geometry_updatedate': '2023-05-18',
#     'oslanduse_updatedate': '2006-01-05',
#     'geometry_evidencedate': '2023-05-18',
#     'nlud_groupdescription': 'Energy production and distribution',
#     'nlud_orderdescription': 'UTILITIES AND INFRASTRUCTURE',
#     'description_updatedate': '2006-01-05',
#     'geometry_capturemethod': 'Desk-Based',
#     'oslanduse_evidencedate': '2006-01-05',
#     'sitetoaddressreference': [{'uprn': 10024998068,
#       'siteid': 'f31855a6-30f1-452d-ba13-35298b3c712f',
#       'siteversiondate': '2024-09-06',
#       'relationshiptype': 'Same As'}],
#     'versionavailabletodate': None,
#     'addresscount_commercial': 1,
#     'oslanduse_capturemethod': 'Automated Process',
#     'addresscount_residential': 0,
#     'description_evidencedate': '2006-01-05',
#     'versionavailablefromdate': '2024-09-07T00:00:00Z',
#     'description_capturemethod': 'Automated Process',
#     'address_classificationcode': 'CU',
#     'address_primarydescription': 'Commercial',
#     'address_classificationsource': 'Matched UPRN',
#     'address_secondarydescription': 'Utility',
#     'address_classificationcorrelation': 'Good'}}]}

# %%
items_auth_limit(
    collection='bld-fts-building-3',
    query_params={
        'bbox':construct_bbox_filter((400000,400000,405000,405000)),
        'bbox-crs':27700,
        'filter':r"(description LIKE '%electricity%')OR(description LIKE '%power%')"
    },
    verbose=True
)
# Out:
# https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-building-3/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&filter=(description LIKE '%electricity%')OR(description LIKE '%power%')&offset=0
# {'type': 'FeatureCollection',
#  'numberOfRequests': 1,
#  'totalNumberReturned': 2,
#  'timeStamp': '2025-01-02T16:57:04.743942',
#  'collection': 'bld-fts-building-3',
#  'source': 'Compiled from code by Geovation from Ordnance Survey',
#  'features': [{'id': '15144597-2b91-426e-9fab-71d5a0bd6831',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-1.9976073, 53.5326704],
#       [-1.9976069, 53.5326724],
#       [-1.9976013, 53.5327018],
#       [-1.9975455, 53.5326955],
#       [-1.9975527, 53.5326724],
#       [-1.9975545, 53.5326668],
#       [-1.9976073, 53.5326704]]]},
#    'properties': {'osid': '15144597-2b91-426e-9fab-71d5a0bd6831',
#     'theme': 'Buildings',
#     'isinsite': True,
#     'changetype': 'New',
#     'buildinguse': 'Unknown',
#     'description': 'Electricity Sub Station',
#     'versiondate': '2024-07-20',
#     'connectivity': 'Standalone',
#     'primarysiteid': 'f31855a6-30f1-452d-ba13-35298b3c712f',
#     'sitereference': [{'siteid': 'f31855a6-30f1-452d-ba13-35298b3c712f',
#       'buildingid': '15144597-2b91-426e-9fab-71d5a0bd6831',
#       'buildingversiondate': '2024-07-20'}],
#     'uprnreference': [],
#     'mainbuildingid': None,
#     'numberoffloors': None,
#     'basementpresence': None,
#     'buildingage_year': None,
#     'geometry_area_m2': 12.332,
#     'buildingpartcount': 1,
#     'buildingage_period': None,
#     'buildingage_source': None,
#     'connectivity_count': 0,
#     'containingsitecount': 1,
#     'geometry_updatedate': '2024-07-18',
#     'constructionmaterial': None,
#     'buildingpartreference': [{'buildingid': '15144597-2b91-426e-9fab-71d5a0bd6831',
#       'buildingpartid': '5862605b-18a8-40e1-9126-3ceef11ce7fd',
#       'buildingversiondate': '2024-07-20'}],
#     'numberoffloors_source': None,
#     'buildingage_updatedate': None,
#     'buildinguse_updatedate': '2024-07-18',
#     'description_updatedate': '2024-07-18',
#     'versionavailabletodate': None,
#     'basementpresence_source': None,
#     'connectivity_updatedate': '2024-07-18',
#     'buildingage_evidencedate': None,
#     'versionavailablefromdate': '2024-07-21T00:00:00Z',
#     'buildingage_capturemethod': None,
#     'mainbuildingid_updatedate': '2024-07-18',
#     'numberoffloors_updatedate': None,
#     'buildinguse_oslandusetiera': 'Utility Or Environmental Protection',
#     'basementpresence_updatedate': None,
#     'constructionmaterial_source': None,
#     'numberoffloors_evidencedate': None,
#     'numberoffloors_capturemethod': None,
#     'basementpresence_evidencedate': None,
#     'mainbuildingid_ismainbuilding': 'Yes',
#     'basementpresence_capturemethod': None,
#     'basementpresence_selfcontained': None,
#     'buildinguse_addresscount_other': 0,
#     'buildinguse_addresscount_total': 0,
#     'constructionmaterial_updatedate': None,
#     'buildingage_thirdpartyprovenance': None,
#     'constructionmaterial_evidencedate': None,
#     'constructionmaterial_capturemethod': None,
#     'buildinguse_addresscount_commercial': 0,
#     'buildinguse_addresscount_residential': 0,
#     'basementpresence_thirdpartyprovenance': None,
#     'constructionmaterial_thirdpartyprovenance': None}},
#   {'id': 'e4a97441-8a26-402b-96de-8df2507facd8',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-1.9819224, 53.530815],
#       [-1.9818926, 53.5308535],
#       [-1.9818196, 53.5308336],
#       [-1.9818493, 53.530795],
#       [-1.9819224, 53.530815]]]},
#    'properties': {'osid': 'e4a97441-8a26-402b-96de-8df2507facd8',
#     'theme': 'Buildings',
#     'isinsite': True,
#     'changetype': 'New',
#     'buildinguse': 'Unknown',
#     'description': 'Hydroelectric Power Generating',
#     'versiondate': '2024-07-20',
#     'connectivity': 'Standalone',
#     'primarysiteid': '754dfe63-d1bc-46da-9b8e-54a0721c1774',
#     'sitereference': [{'siteid': '754dfe63-d1bc-46da-9b8e-54a0721c1774',
#       'buildingid': 'e4a97441-8a26-402b-96de-8df2507facd8',
#       'buildingversiondate': '2024-07-20'}],
#     'uprnreference': [],
#     'mainbuildingid': None,
#     'numberoffloors': None,
#     'basementpresence': None,
#     'buildingage_year': None,
#     'geometry_area_m2': 25.163,
#     'buildingpartcount': 1,
#     'buildingage_period': None,
#     'buildingage_source': None,
#     'connectivity_count': 0,
#     'containingsitecount': 1,
#     'geometry_updatedate': '2024-07-18',
#     'constructionmaterial': None,
#     'buildingpartreference': [{'buildingid': 'e4a97441-8a26-402b-96de-8df2507facd8',
#       'buildingpartid': 'b0a8adaf-dcef-4820-8284-e01f2c79b487',
#       'buildingversiondate': '2024-07-20'}],
#     'numberoffloors_source': None,
#     'buildingage_updatedate': None,
#     'buildinguse_updatedate': '2024-07-18',
#     'description_updatedate': '2024-07-18',
#     'versionavailabletodate': None,
#     'basementpresence_source': None,
#     'connectivity_updatedate': '2024-07-18',
#     'buildingage_evidencedate': None,
#     'versionavailablefromdate': '2024-07-21T00:00:00Z',
#     'buildingage_capturemethod': None,
#     'mainbuildingid_updatedate': '2024-07-18',
#     'numberoffloors_updatedate': None,
#     'buildinguse_oslandusetiera': 'Utility Or Environmental Protection',
#     'basementpresence_updatedate': None,
#     'constructionmaterial_source': None,
#     'numberoffloors_evidencedate': None,
#     'numberoffloors_capturemethod': None,
#     'basementpresence_evidencedate': None,
#     'mainbuildingid_ismainbuilding': 'Yes',
#     'basementpresence_capturemethod': None,
#     'basementpresence_selfcontained': None,
#     'buildinguse_addresscount_other': 0,
#     'buildinguse_addresscount_total': 0,
#     'constructionmaterial_updatedate': None,
#     'buildingage_thirdpartyprovenance': None,
#     'constructionmaterial_evidencedate': None,
#     'constructionmaterial_capturemethod': None,
#     'buildinguse_addresscount_commercial': 0,
#     'buildinguse_addresscount_residential': 0,
#     'basementpresence_thirdpartyprovenance': None,
#     'constructionmaterial_thirdpartyprovenance': None}}]}

# %%
items_auth_limit(
    collection='wtr-ntwk-waterlink-1',
    query_params={
        'bbox':construct_bbox_filter((400000,400000,405000,405000)),
        'bbox-crs':27700
    },
    verbose=True
)
# Out:
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=0
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=100
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=200
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=300
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=400
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=500
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=600
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=700
# https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink-1/items/?bbox=400000,400000,405000,405000&bbox-crs=http://www.opengis.net/def/crs/EPSG/0/27700&offset=800
# {'type': 'FeatureCollection',
#  'numberOfRequests': 9,
#  'totalNumberReturned': 810,
#  'timeStamp': '2025-01-02T16:57:10.632710',
#  'collection': 'wtr-ntwk-waterlink-1',
#  'source': 'Compiled from code by Geovation from Ordnance Survey',
#  'features': [{'id': '00415101-a6d2-4caf-b7e6-6a5faa1ea097',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9719947, 53.5001669],
#      [-1.9720123, 53.5001418],
#      [-1.9720758, 53.5000984]]},
#    'properties': {'osid': '00415101-a6d2-4caf-b7e6-6a5faa1ea097',
#     'toid': 'osgb5000005148131569',
#     'theme': 'Water',
#     'width': 7.8,
#     'nameid': 'b2bb68d0-40d9-4baf-a6b4-f56568c760a6',
#     'endnode': 'e5d8b181-8d04-4ef7-ad83-8af7c3e9e7ed',
#     'primacy': 1,
#     'gradient': 2.35,
#     'startnode': '5d6c3b03-e6a0-475c-9c0d-8d1f56003ccd',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': 'Ogden Brook',
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 9.435,
#     'geometry_source': 'Ordnance Survey Area',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '01521dc4-4572-42af-a309-8d82b47c1ebc',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9713087, 53.5404581],
#      [-1.9713923, 53.5403012],
#      [-1.9714193, 53.5402195],
#      [-1.9714282, 53.5401579],
#      [-1.9714216, 53.5399183],
#      [-1.9714796, 53.5396958],
#      [-1.971523, 53.5396019],
#      [-1.971627, 53.5392676],
#      [-1.9717098, 53.5386913]]},
#    'properties': {'osid': '01521dc4-4572-42af-a309-8d82b47c1ebc',
#     'toid': 'osgb5000005149467969',
#     'theme': 'Water',
#     'width': 4.5,
#     'nameid': None,
#     'endnode': '66388393-8fd0-439c-82df-b42a19657817',
#     'primacy': 1,
#     'gradient': 1.34,
#     'startnode': '1e219c76-0f94-44e0-95a6-c856263431f3',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Drain',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 199.188,
#     'geometry_source': 'Ordnance Survey Area',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2017-01-17',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Rural',
#     'geometry_evidencedate': '2016-04-20',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '01f2d412-a453-4ec0-9b3a-c249de045ee9',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9448892, 53.5300663],
#      [-1.944942, 53.5300798],
#      [-1.9450551, 53.5300619],
#      [-1.9452589, 53.5299721],
#      [-1.945372, 53.5299767],
#      [-1.945553, 53.5300442],
#      [-1.9457718, 53.5300038],
#      [-1.9458471, 53.5300353],
#      [-1.9458999, 53.5300982]]},
#    'properties': {'osid': '01f2d412-a453-4ec0-9b3a-c249de045ee9',
#     'toid': 'osgb5000005149659510',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'bb1500d8-1e9b-4ccb-b54e-2ed51591c71e',
#     'primacy': 1,
#     'gradient': 1.98,
#     'startnode': '15ffeae9-b1bf-47ee-887d-d18263cadff9',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 79.15,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '0231c226-835b-42a8-8073-d5952219c1ee',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9397689, 53.5291515],
#      [-1.9397839, 53.529201],
#      [-1.9397084, 53.5292459],
#      [-1.9397309, 53.5293178],
#      [-1.939663, 53.5293807],
#      [-1.9396855, 53.5294391],
#      [-1.9398815, 53.5295426],
#      [-1.9399794, 53.5296505],
#      [-1.9402508, 53.5297585],
#      [-1.9403186, 53.5298214],
#      [-1.9403336, 53.5298709],
#      [-1.9402203, 53.5299337],
#      [-1.9402202, 53.5300056],
#      [-1.9404163, 53.5300372],
#      [-1.9405746, 53.5301541],
#      [-1.9407631, 53.5302036],
#      [-1.9407932, 53.5302216],
#      [-1.9408082, 53.5303115],
#      [-1.9408911, 53.530361],
#      [-1.941057, 53.5303611],
#      [-1.9411853, 53.5303252],
#      [-1.9414191, 53.5303388]]},
#    'properties': {'osid': '0231c226-835b-42a8-8073-d5952219c1ee',
#     'toid': 'osgb5000005144182378',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'f6557cd1-d347-474e-b902-23a9ae0ac356',
#     'primacy': 1,
#     'gradient': 4.03,
#     'startnode': '2759a907-b031-418f-99ed-e59f9d28b67b',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 221.055,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '024a08c4-7d47-4a9d-be02-8c5c4ccd5521',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9809895, 53.5118133],
#      [-1.9810573, 53.5118133],
#      [-1.981095, 53.5117908],
#      [-1.9810951, 53.5115841],
#      [-1.9813742, 53.5114268],
#      [-1.9814797, 53.5113999],
#      [-1.9816531, 53.5113909],
#      [-1.9818039, 53.5113415],
#      [-1.9821734, 53.5112966],
#      [-1.9824222, 53.5111708],
#      [-1.9825806, 53.5111439]]},
#    'properties': {'osid': '024a08c4-7d47-4a9d-be02-8c5c4ccd5521',
#     'toid': 'osgb5000005147933524',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'f26da005-ada9-43fa-9351-0b06fe7ba597',
#     'primacy': 1,
#     'gradient': 7.36,
#     'startnode': '02920b5e-f33d-43c0-b8cb-46e4b837b856',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 144.637,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '0258805b-96b1-450b-9b70-e4f99178749e',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9364502, 53.5138427],
#      [-1.93657, 53.5138252],
#      [-1.936768, 53.5137788],
#      [-1.9368398, 53.5137491],
#      [-1.9369296, 53.513726],
#      [-1.9370266, 53.5137019],
#      [-1.937076, 53.5136935],
#      [-1.9371611, 53.5136803],
#      [-1.9372932, 53.5136747]]},
#    'properties': {'osid': '0258805b-96b1-450b-9b70-e4f99178749e',
#     'toid': 'osgb5000005219670322',
#     'theme': 'Water',
#     'width': 119.4,
#     'nameid': '57aa629e-92f4-4650-b0c4-c2341b9a89d9',
#     'endnode': 'c9dd177b-68fd-4063-9817-6f48773c3d08',
#     'primacy': 1,
#     'gradient': 0.0,
#     'startnode': '58894252-296b-4ac0-9647-0f27d1cf29cf',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': 'Chew Brook',
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Reservoir',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Regional',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 59.563,
#     'geometry_source': 'Ordnance Survey Area',
#     'namesecondaryid': '5d8429e1-3385-48d3-9e69-17ac39574c7e',
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2017-12-22',
#     'namesecondary1_text': 'Chew Reservoir',
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2017-12-22',
#     'description_updatedate': '2017-12-22',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2017-12-22',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '0264d957-5ccf-4028-8edf-cfbafed07eac',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9616986, 53.5170534],
#      [-1.9620605, 53.51704],
#      [-1.9625054, 53.5170716],
#      [-1.9628522, 53.5171212],
#      [-1.9630483, 53.5171167],
#      [-1.9631689, 53.5171168],
#      [-1.9634781, 53.5171214],
#      [-1.9637119, 53.5170945],
#      [-1.9640059, 53.517153],
#      [-1.9641114, 53.5172339],
#      [-1.9640887, 53.5173508]]},
#    'properties': {'osid': '0264d957-5ccf-4028-8edf-cfbafed07eac',
#     'toid': 'osgb5000005144940534',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '50e0664e-dbd4-455c-9240-25d5aca02ca3',
#     'primacy': 1,
#     'gradient': 31.42,
#     'startnode': 'f84d663d-d880-4d76-b0af-c375fef829fc',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 179.748,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '027dc174-4896-487d-8132-ef88f6ab8a33',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9849038, 53.5237286],
#      [-1.9848168, 53.5238028],
#      [-1.9847465, 53.523846],
#      [-1.9846515, 53.5239017],
#      [-1.9846092, 53.5239274],
#      [-1.9845693, 53.5239397],
#      [-1.9845039, 53.5239516],
#      [-1.9844671, 53.5239525],
#      [-1.984427, 53.5239464],
#      [-1.9843525, 53.5239201],
#      [-1.9843159, 53.5239134],
#      [-1.984281, 53.5239049],
#      [-1.9842326, 53.523898],
#      [-1.9841822, 53.5238922],
#      [-1.9841338, 53.5238863],
#      [-1.9840819, 53.5238815],
#      [-1.9840442, 53.5238797],
#      [-1.9839567, 53.5238365],
#      [-1.983893, 53.5238082],
#      [-1.9838464, 53.5237909],
#      [-1.9838132, 53.5237782]]},
#    'properties': {'osid': '027dc174-4896-487d-8132-ef88f6ab8a33',
#     'toid': 'osgb5000005274113380',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '96e3c6c3-2060-4460-94f3-31c5efcbb5fe',
#     'primacy': 1,
#     'gradient': 12.28,
#     'startnode': 'b06d8da9-acfc-4d5d-8cf8-0ed4174831b1',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 88.108,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2020-12-15',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Rural',
#     'geometry_evidencedate': '2020-05-29',
#     'description_updatedate': '2020-12-15',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2020-05-29',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '028c126f-d956-4ef5-8cd1-f1c0e6cfa190',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.948443, 53.5039252],
#      [-1.9486315, 53.5039433],
#      [-1.9488577, 53.5038715],
#      [-1.9490085, 53.5037996],
#      [-1.9494609, 53.5037729],
#      [-1.9495816, 53.5036695],
#      [-1.9496796, 53.5036741],
#      [-1.9497927, 53.5036292],
#      [-1.9499284, 53.5036337],
#      [-1.9499963, 53.5035663],
#      [-1.9501697, 53.5035574],
#      [-1.9501848, 53.5035035],
#      [-1.9504261, 53.5034946],
#      [-1.9505015, 53.5034722],
#      [-1.9505619, 53.5033913],
#      [-1.9506524, 53.5033599],
#      [-1.9507204, 53.5031891],
#      [-1.9508863, 53.5031218],
#      [-1.9509316, 53.5030409],
#      [-1.9510901, 53.5028972],
#      [-1.9510977, 53.5028477],
#      [-1.9509922, 53.5027713],
#      [-1.9510978, 53.5027309],
#      [-1.9511281, 53.5026365],
#      [-1.9512261, 53.5025781],
#      [-1.9512263, 53.5024253]]},
#    'properties': {'osid': '028c126f-d956-4ef5-8cd1-f1c0e6cfa190',
#     'toid': 'osgb5000005150151003',
#     'theme': 'Water',
#     'width': None,
#     'nameid': 'f35c85aa-1799-48f7-8a0a-cb7e5766a99d',
#     'endnode': 'ea582ea2-e617-4209-9190-66b569318ca5',
#     'primacy': 1,
#     'gradient': 3.98,
#     'startnode': '18eeb045-8c0e-4710-a299-3b30e58b1efc',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': 'Arnfield Gutter',
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 299.16,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '02aaabe6-1b54-4351-878b-04f079ce99b6',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9498972, 53.5174715],
#      [-1.9499274, 53.5173996],
#      [-1.9500935, 53.5172963],
#      [-1.9501312, 53.5172199],
#      [-1.9503653, 53.5169908],
#      [-1.9503578, 53.5168919],
#      [-1.9503881, 53.516811],
#      [-1.950358, 53.5167166],
#      [-1.9503958, 53.5166672],
#      [-1.9503054, 53.5165638],
#      [-1.9501923, 53.5165503],
#      [-1.949921, 53.5164648],
#      [-1.9499135, 53.5164198],
#      [-1.9499889, 53.5163884],
#      [-1.9499211, 53.5163299],
#      [-1.949974, 53.5162581],
#      [-1.9499364, 53.5161637],
#      [-1.9498912, 53.5161412],
#      [-1.9496047, 53.5161411],
#      [-1.9494088, 53.5159747],
#      [-1.9492617, 53.5158911],
#      [-1.9492342, 53.5158576],
#      [-1.9492042, 53.5158561],
#      [-1.9491647, 53.5158618],
#      [-1.9491444, 53.5158518],
#      [-1.9491336, 53.515839],
#      [-1.9491313, 53.5158254],
#      [-1.9491618, 53.5158059],
#      [-1.9491971, 53.5157855],
#      [-1.9492211, 53.5157513],
#      [-1.9492295, 53.5157177],
#      [-1.949225, 53.5156754],
#      [-1.9492963, 53.5154848],
#      [-1.9493643, 53.5153859],
#      [-1.9494624, 53.5153051],
#      [-1.9494776, 53.5152332],
#      [-1.9494325, 53.5150803],
#      [-1.9493948, 53.5150354]]},
#    'properties': {'osid': '02aaabe6-1b54-4351-878b-04f079ce99b6',
#     'toid': 'osgb5000005149874274',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '35caa0e8-1c9a-427e-bbd8-7c4d52384a67',
#     'primacy': 1,
#     'gradient': 1.38,
#     'startnode': '88f99c29-32c9-4c8c-b5c3-77980d4541fa',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 346.533,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2019-02-04',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2018-06-27',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '02defd24-1dd6-49be-ae10-b5348c8bae28',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9958349, 53.5117653],
#      [-1.9959857, 53.5117294],
#      [-1.9961968, 53.5117249],
#      [-1.9964607, 53.5116305],
#      [-1.9967095, 53.5116081],
#      [-1.9968754, 53.5115182],
#      [-1.9971242, 53.5114777],
#      [-1.9973353, 53.5113923],
#      [-1.9975162, 53.5113564],
#      [-1.997652, 53.511289],
#      [-1.9979611, 53.5112036],
#      [-1.9981269, 53.5111317],
#      [-1.9983004, 53.5110193],
#      [-1.9985416, 53.5107812],
#      [-1.9987603, 53.5106598],
#      [-1.9988206, 53.5104845],
#      [-1.9993483, 53.5101565],
#      [-1.999861, 53.509707],
#      [-1.9999439, 53.5095363],
#      [-1.9999892, 53.509361],
#      [-1.9999665, 53.5091767]]},
#    'properties': {'osid': '02defd24-1dd6-49be-ae10-b5348c8bae28',
#     'toid': 'osgb5000005149683563',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '2ed3ad46-c4bf-4e40-a32c-c08eabcf539e',
#     'primacy': 1,
#     'gradient': 13.41,
#     'startnode': 'f1e427fb-cfe6-4807-91ad-0c8893c2d0e7',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 430.081,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '02ff9728-8990-49ba-bfd7-fed40aa8be93',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-2.0003738, 53.5138957],
#      [-2.0008337, 53.5137909],
#      [-2.0010901, 53.5138088],
#      [-2.0012182, 53.5138223],
#      [-2.0012936, 53.5138448],
#      [-2.0014671, 53.5138448],
#      [-2.001485, 53.5138509],
#      [-2.0015082, 53.513856],
#      [-2.0015339, 53.5138589],
#      [-2.0015583, 53.513861],
#      [-2.0015829, 53.5138611],
#      [-2.0015927, 53.513862],
#      [-2.0016034, 53.5138621],
#      [-2.0016636, 53.5138589],
#      [-2.0016718, 53.5138591],
#      [-2.0016813, 53.51386],
#      [-2.0016937, 53.5138617],
#      [-2.0017032, 53.5138651],
#      [-2.0017083, 53.5138701],
#      [-2.0017138, 53.5138726],
#      [-2.001719, 53.5138733],
#      [-2.0017261, 53.5138751],
#      [-2.0017341, 53.5138744],
#      [-2.0017792, 53.5138775],
#      [-2.0017969, 53.5138784],
#      [-2.0018145, 53.513881],
#      [-2.0018294, 53.5138846],
#      [-2.0018429, 53.5138896],
#      [-2.0018901, 53.5139101],
#      [-2.0019079, 53.5139162],
#      [-2.0019288, 53.5139214],
#      [-2.0019499, 53.5139256],
#      [-2.0020104, 53.5139329],
#      [-2.0020302, 53.5139344],
#      [-2.0020464, 53.5139296]]},
#    'properties': {'osid': '02ff9728-8990-49ba-bfd7-fed40aa8be93',
#     'toid': 'osgb5000005145337572',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'fecb5c82-4157-4e4c-b3b8-4629bd0e2561',
#     'primacy': 1,
#     'gradient': 17.32,
#     'startnode': 'd5826980-ae8c-4f0a-8e2e-2d48cadd65cc',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 116.479,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2015-11-05',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2015-11-05',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '030d3194-944a-4a9e-9603-30c84808115f',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9446445, 53.5145018], [-1.9449866, 53.5145077]]},
#    'properties': {'osid': '030d3194-944a-4a9e-9603-30c84808115f',
#     'toid': 'osgb5000005219670369',
#     'theme': 'Water',
#     'width': 119.4,
#     'nameid': '57aa629e-92f4-4650-b0c4-c2341b9a89d9',
#     'endnode': '647dcd98-b229-4181-bf30-7f11925f9802',
#     'primacy': 1,
#     'gradient': 0.0,
#     'startnode': '9de474c9-91fc-4720-ab3b-e5cc870aa376',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': 'Chew Brook',
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Reservoir',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Regional',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 22.699,
#     'geometry_source': 'Ordnance Survey Area',
#     'namesecondaryid': '5d8429e1-3385-48d3-9e69-17ac39574c7e',
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2017-12-22',
#     'namesecondary1_text': 'Chew Reservoir',
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2017-12-22',
#     'description_updatedate': '2017-12-22',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2017-12-22',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '032b619c-f5d9-4984-ba82-beefccfb9f8d',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9821642, 53.5241865], [-1.9821114, 53.5243016]]},
#    'properties': {'osid': '032b619c-f5d9-4984-ba82-beefccfb9f8d',
#     'toid': 'osgb5000005242648060',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'e161fb0c-b3ed-491d-853c-30914a536484',
#     'primacy': 1,
#     'gradient': 14.12,
#     'startnode': '768f40d2-6e0c-46c3-8e6b-befad4fa9154',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 13.27,
#     'geometry_source': 'Ordnance Survey Inferred',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2019-01-31',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': None,
#     'geometry_evidencedate': '2018-06-27',
#     'description_updatedate': '2019-01-31',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2018-06-27',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '03942d4a-87f1-4c67-bff3-bad8bbd3525b',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9460836, 53.5099105],
#      [-1.9460383, 53.5099734],
#      [-1.9460533, 53.5100183],
#      [-1.9461965, 53.5100993],
#      [-1.9463319, 53.5103196],
#      [-1.9464374, 53.5103691],
#      [-1.946475, 53.510423],
#      [-1.9465579, 53.510468],
#      [-1.9465879, 53.5105714],
#      [-1.9467084, 53.5106478],
#      [-1.9467989, 53.5106748],
#      [-1.9468741, 53.5108187],
#      [-1.9471606, 53.5108503],
#      [-1.9476654, 53.5110707],
#      [-1.947771, 53.5110887],
#      [-1.9479444, 53.5110798],
#      [-1.948193, 53.5112148],
#      [-1.9483966, 53.5112373],
#      [-1.9487705, 53.5114664]]},
#    'properties': {'osid': '03942d4a-87f1-4c67-bff3-bad8bbd3525b',
#     'toid': 'osgb5000005147896587',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'f7a8612d-d554-4e55-8a09-d32e7225924f',
#     'primacy': 1,
#     'gradient': 9.47,
#     'startnode': 'e38aa4ec-45ff-49f4-9fe1-7c4e034e7063',
#     'watertype': 'Inland',
#     'changetype': 'Modified Geometry And Attributes',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2024-07-01',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 272.793,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2024-04-12',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2024-04-12',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2024-07-02T00:00:00Z'}},
#   {'id': '03e6c48b-fb3a-45a1-ad9c-5c270c71c03a',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9334822, 53.526618],
#      [-1.9333616, 53.5265865],
#      [-1.9332032, 53.5265999],
#      [-1.9330598, 53.5266357],
#      [-1.9328034, 53.5266266],
#      [-1.9327205, 53.5265906],
#      [-1.9325696, 53.5266265],
#      [-1.9322981, 53.5266083],
#      [-1.9321925, 53.5266397],
#      [-1.9319586, 53.5266711],
#      [-1.9317624, 53.5267384],
#      [-1.9313022, 53.5268459],
#      [-1.9310531, 53.5269312],
#      [-1.9308646, 53.5269401],
#      [-1.9306609, 53.5269759],
#      [-1.9305325, 53.5270522],
#      [-1.9304269, 53.5270701],
#      [-1.9303288, 53.5271285],
#      [-1.9301854, 53.5271329],
#      [-1.9299817, 53.5271732],
#      [-1.9299212, 53.5272945],
#      [-1.9297099, 53.5273843],
#      [-1.9296795, 53.5274787],
#      [-1.9295889, 53.527564],
#      [-1.9294981, 53.5277167],
#      [-1.9294829, 53.5277796],
#      [-1.929528, 53.52791],
#      [-1.9293921, 53.5280088],
#      [-1.9294673, 53.5281392]]},
#    'properties': {'osid': '03e6c48b-fb3a-45a1-ad9c-5c270c71c03a',
#     'toid': 'osgb5000005144147730',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '017e2a18-92a7-4f60-8b8f-723913282c69',
#     'primacy': 1,
#     'gradient': 4.91,
#     'startnode': '83cb450a-d031-4922-881a-ced32127c78a',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 374.421,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '0479e5b6-681c-4343-9d18-b8a69d74dadd',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9579979, 53.5307458],
#      [-1.9578696, 53.5308042],
#      [-1.9578318, 53.5308896],
#      [-1.9579374, 53.5309705],
#      [-1.9579373, 53.5310469],
#      [-1.9580126, 53.5311368],
#      [-1.958005, 53.5312042],
#      [-1.9580803, 53.5313166],
#      [-1.9581482, 53.5313661],
#      [-1.9581556, 53.5315189],
#      [-1.9582535, 53.5316178],
#      [-1.9582987, 53.5317391],
#      [-1.9581402, 53.5318514],
#      [-1.9582003, 53.5320267],
#      [-1.9581323, 53.532157],
#      [-1.9581624, 53.5322604],
#      [-1.9579662, 53.5323862],
#      [-1.9579661, 53.5324311],
#      [-1.9580113, 53.5324805],
#      [-1.9579962, 53.5325345],
#      [-1.9576638, 53.5330152]]},
#    'properties': {'osid': '0479e5b6-681c-4343-9d18-b8a69d74dadd',
#     'toid': 'osgb5000005150672232',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'd7758e98-f646-4bb6-8bde-5a919b6a4c63',
#     'primacy': 1,
#     'gradient': 2.83,
#     'startnode': 'f3ad4d16-9d1f-4ac8-b766-206f690806b8',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 280.691,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '04f845b2-7245-458b-831a-a11287898a52',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9709729, 53.5064946],
#      [-1.9710408, 53.5064317],
#      [-1.9712822, 53.506261],
#      [-1.9713199, 53.506198],
#      [-1.9713275, 53.5061037],
#      [-1.971516, 53.5059869],
#      [-1.9715161, 53.5059015],
#      [-1.971682, 53.5057532],
#      [-1.9718257, 53.5050926],
#      [-1.971871, 53.5050162],
#      [-1.9720218, 53.5049129],
#      [-1.9720445, 53.504787],
#      [-1.972135, 53.5046927],
#      [-1.9721653, 53.5045578]]},
#    'properties': {'osid': '04f845b2-7245-458b-831a-a11287898a52',
#     'toid': 'osgb5000005146663686',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '485244e4-241d-45c9-9d53-503d0227b936',
#     'primacy': 1,
#     'gradient': 12.25,
#     'startnode': '87ff8fbf-5733-4d4b-8d16-7120364cd435',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 238.143,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '05132007-5e28-43ec-baca-c566982011b7',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9446762, 53.5314234],
#      [-1.9447893, 53.5315089],
#      [-1.9448042, 53.5315853],
#      [-1.9446307, 53.5316121],
#      [-1.9446005, 53.531675],
#      [-1.9444797, 53.5317154],
#      [-1.9444042, 53.5317693],
#      [-1.9443662, 53.531994],
#      [-1.9442227, 53.5321108],
#      [-1.9440265, 53.5322051],
#      [-1.944034, 53.532241],
#      [-1.9441998, 53.53234],
#      [-1.9442375, 53.5323894],
#      [-1.9441543, 53.5325017],
#      [-1.9441694, 53.5325557],
#      [-1.9441316, 53.5326186],
#      [-1.944139, 53.5326905],
#      [-1.9442295, 53.532749],
#      [-1.9442445, 53.5327894],
#      [-1.9442369, 53.5328164],
#      [-1.9441539, 53.5328613],
#      [-1.9441537, 53.5329961],
#      [-1.9440933, 53.533014],
#      [-1.9439198, 53.533014],
#      [-1.9439047, 53.5330724],
#      [-1.9438367, 53.5331128],
#      [-1.9435273, 53.533234],
#      [-1.9434894, 53.5333508]]},
#    'properties': {'osid': '05132007-5e28-43ec-baca-c566982011b7',
#     'toid': 'osgb5000005145966341',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'dc199582-5f6a-460a-a2f1-2170afeefaf3',
#     'primacy': 1,
#     'gradient': 3.48,
#     'startnode': '9639cd16-dc4e-4882-8f80-430db2082f1b',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 281.197,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '06443250-251a-4472-8ef7-b88ca00de102',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9576638, 53.5330152], [-1.9571252, 53.534026]]},
#    'properties': {'osid': '06443250-251a-4472-8ef7-b88ca00de102',
#     'toid': 'osgb5000005146996759',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'ca3b17f6-2b21-4e4a-a86f-4452ae29f321',
#     'primacy': 1,
#     'gradient': 87.93,
#     'startnode': 'd7758e98-f646-4bb6-8bde-5a919b6a4c63',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 117.986,
#     'geometry_source': 'National Authority Inferred',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2017-01-18',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': None,
#     'geometry_evidencedate': '2016-04-20',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': '0656d2c3-6a56-4e5f-b3ee-d8c9daa8915c',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9476277, 53.498716],
#      [-1.947643, 53.4985542],
#      [-1.9477637, 53.4984824],
#      [-1.9478015, 53.4983701],
#      [-1.9478694, 53.4982937],
#      [-1.9478397, 53.4978982],
#      [-1.947772, 53.4978038],
#      [-1.9478174, 53.4977049],
#      [-1.9477572, 53.4975611],
#      [-1.9478403, 53.4974712],
#      [-1.9478405, 53.4972735],
#      [-1.9481649, 53.497013],
#      [-1.9481876, 53.4969366],
#      [-1.9481125, 53.4967433],
#      [-1.9481427, 53.4967073],
#      [-1.9482256, 53.4966444],
#      [-1.9482634, 53.496613],
#      [-1.9483086, 53.4965861],
#      [-1.9483388, 53.4965591],
#      [-1.9483388, 53.4965546],
#      [-1.948369, 53.4965411],
#      [-1.9483991, 53.4965232],
#      [-1.9484218, 53.4965052],
#      [-1.948467, 53.4964783],
#      [-1.9484972, 53.4964648],
#      [-1.9485047, 53.4964558],
#      [-1.9485047, 53.4964468],
#      [-1.9484972, 53.4964378],
#      [-1.9484897, 53.4964333],
#      [-1.9484746, 53.4964288],
#      [-1.948452, 53.4964288],
#      [-1.9484294, 53.4964198],
#      [-1.9484143, 53.4964108],
#      [-1.9484144, 53.4964018],
#      [-1.9483918, 53.4963928],
#      [-1.9483842, 53.4963794],
#      [-1.9483843, 53.4963569],
#      [-1.9483692, 53.4963389],
#      [-1.9483692, 53.4963344],
#      [-1.9483768, 53.4963254],
#      [-1.9483918, 53.4963164],
#      [-1.9484069, 53.496312],
#      [-1.9484371, 53.496312],
#      [-1.9484672, 53.496303],
#      [-1.9484748, 53.496294],
#      [-1.9484823, 53.4962895],
#      [-1.9484824, 53.4962536],
#      [-1.9484748, 53.4962491],
#      [-1.9484673, 53.4962131],
#      [-1.9484448, 53.4961816],
#      [-1.9484373, 53.4961592],
#      [-1.9484298, 53.4961232],
#      [-1.9484298, 53.4961052],
#      [-1.9484449, 53.4960468],
#      [-1.9484525, 53.4960243],
#      [-1.9484978, 53.4959614],
#      [-1.9485053, 53.4959525],
#      [-1.9485204, 53.495948],
#      [-1.948528, 53.4959345],
#      [-1.9485355, 53.4959255],
#      [-1.9485355, 53.4959165],
#      [-1.948528, 53.4959075],
#      [-1.9485282, 53.4957592],
#      [-1.9485357, 53.4957547],
#      [-1.9485433, 53.4957457],
#      [-1.948581, 53.4957143],
#      [-1.9485961, 53.4957098],
#      [-1.9486036, 53.4957008],
#      [-1.9486112, 53.4956963],
#      [-1.9486112, 53.4956828],
#      [-1.9486187, 53.4956559],
#      [-1.9486188, 53.4955975],
# ...
#     'namesecondary2_language': None,
#     'description_evidencedate': '2020-05-29',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': 'fd50608d-77dc-4920-80c0-e48533cb0cd1',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.942078, 53.5065805], [-1.9412782, 53.5064926]]},
#    'properties': {'osid': 'fd50608d-77dc-4920-80c0-e48533cb0cd1',
#     'toid': 'osgb5000005147293083',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '7401289c-bbec-4442-803d-bdb075f9a2cc',
#     'primacy': 1,
#     'gradient': 4.57,
#     'startnode': '9315dff3-98bc-45fe-920a-d4ff19c2079b',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 53.935,
#     'geometry_source': 'National Authority Inferred',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': None,
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': 'fdc4868f-f175-4e90-8657-461f8ff340c7',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9641716, 53.5173778],
#      [-1.9639829, 53.5176069],
#      [-1.9639223, 53.5179799],
#      [-1.9639674, 53.5180473],
#      [-1.9640503, 53.5181013],
#      [-1.9642991, 53.5181643],
#      [-1.9645328, 53.5183037],
#      [-1.9646383, 53.5184026],
#      [-1.9646985, 53.5185284],
#      [-1.9646985, 53.518543],
#      [-1.9646975, 53.5185658],
#      [-1.9646909, 53.5186048],
#      [-1.9646305, 53.5186947],
#      [-1.964638, 53.5187621],
#      [-1.9648942, 53.5189554],
#      [-1.9649242, 53.5191038]]},
#    'properties': {'osid': 'fdc4868f-f175-4e90-8657-461f8ff340c7',
#     'toid': 'osgb5000005149445697',
#     'theme': 'Water',
#     'width': None,
#     'nameid': '57aa629e-92f4-4650-b0c4-c2341b9a89d9',
#     'endnode': '32b777b2-1e4a-470b-8a9e-8763b5fbd925',
#     'primacy': 1,
#     'gradient': 8.18,
#     'startnode': '4207acf8-8682-4ac7-81e1-2ca02a89a155',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': 'Chew Brook',
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Regional',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 224.59,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2015-11-04',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2015-11-04',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': 'fdea90a0-6362-4d4b-a60a-78622f6579f8',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9412063, 53.5039713],
#      [-1.941131, 53.5039083],
#      [-1.9411537, 53.5038185],
#      [-1.9410408, 53.5037465],
#      [-1.9410032, 53.5036656],
#      [-1.9409128, 53.5036341],
#      [-1.9408828, 53.5035307],
#      [-1.9407924, 53.5034632],
#      [-1.9407548, 53.5034003],
#      [-1.9406267, 53.5033373],
#      [-1.9406043, 53.5032384],
#      [-1.9405289, 53.5032025],
#      [-1.9404913, 53.503135],
#      [-1.9403482, 53.5030765],
#      [-1.9403482, 53.503072]]},
#    'properties': {'osid': 'fdea90a0-6362-4d4b-a60a-78622f6579f8',
#     'toid': 'osgb5000005146362471',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '6ae432a2-7518-455d-bdd3-528f33dbc99d',
#     'primacy': 1,
#     'gradient': 3.32,
#     'startnode': '3ab7c580-226b-4127-bf4e-e47d6e2bd814',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 123.11,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': 'fe29dd36-d15e-4269-b7fb-23f4240c62cc',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.946955, 53.5185533],
#      [-1.9467515, 53.5184723],
#      [-1.9467065, 53.518306],
#      [-1.9463825, 53.5181351],
#      [-1.9463148, 53.5179373],
#      [-1.9461566, 53.5178518],
#      [-1.9461341, 53.5177395],
#      [-1.9460964, 53.5177125],
#      [-1.9457799, 53.517591],
#      [-1.9457195, 53.5176045],
#      [-1.9455537, 53.5175504],
#      [-1.9453576, 53.5175683],
#      [-1.9452673, 53.5174784],
#      [-1.9451918, 53.5175053],
#      [-1.9451767, 53.5175683],
#      [-1.9451314, 53.5175772]]},
#    'properties': {'osid': 'fe29dd36-d15e-4269-b7fb-23f4240c62cc',
#     'toid': 'osgb5000005150092902',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': 'bf74b265-d5f3-4ddc-b33f-11be3e7ed050',
#     'primacy': 1,
#     'gradient': 2.37,
#     'startnode': 'edbd1942-2931-460a-ba6f-08f071f943bc',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 199.415,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': 'feddf0ec-0d3f-42d6-b5a7-a3d6a648adfe',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9718511, 53.5252868],
#      [-1.9718794, 53.5252852],
#      [-1.9719285, 53.5252709]]},
#    'properties': {'osid': 'feddf0ec-0d3f-42d6-b5a7-a3d6a648adfe',
#     'toid': 'osgb5000005199569299',
#     'theme': 'Water',
#     'width': 2.0,
#     'nameid': None,
#     'endnode': '895f0137-0fd3-4def-9448-2b1b58a4839c',
#     'primacy': 1,
#     'gradient': 9.58,
#     'startnode': '0ee9c0e1-248c-4c3e-8786-298b261f4875',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Still Water',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 5.512,
#     'geometry_source': 'Ordnance Survey Area',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2017-02-02',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Rural',
#     'geometry_evidencedate': '2016-04-20',
#     'description_updatedate': '2017-02-02',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2016-04-20',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': 'ff12bbac-c59e-4d22-9f64-aa1cc053abe4',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9542056, 53.5078106],
#      [-1.9542207, 53.5078196],
#      [-1.9542961, 53.5078151],
#      [-1.9543866, 53.5077792],
#      [-1.9545449, 53.5078062]]},
#    'properties': {'osid': 'ff12bbac-c59e-4d22-9f64-aa1cc053abe4',
#     'toid': 'osgb5000005326149780',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '8170ed26-5ff1-43a3-8feb-7667c079d5a8',
#     'primacy': 1,
#     'gradient': 5.08,
#     'startnode': '0327c507-2b81-40f6-b854-76e925ebdc59',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2023-10-10',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': None,
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 24.57,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2023-07-14',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2023-04-04',
#     'description_updatedate': '2023-07-14',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2023-04-04',
#     'versionavailablefromdate': '2023-10-11T00:00:00Z'}},
#   {'id': 'ffac6abc-9924-4fcc-85a3-1a46b135cecf',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9455998, 53.510917],
#      [-1.9455922, 53.5109754],
#      [-1.9456223, 53.5110159],
#      [-1.9458183, 53.5110834],
#      [-1.9458785, 53.5111463],
#      [-1.9459463, 53.5111598],
#      [-1.9460291, 53.5112498],
#      [-1.9460894, 53.5112723],
#      [-1.9460666, 53.5114071],
#      [-1.9459987, 53.5114879],
#      [-1.9460589, 53.5115734],
#      [-1.946021, 53.5117127],
#      [-1.9461792, 53.5118071],
#      [-1.9462468, 53.5120363],
#      [-1.946209, 53.5121082],
#      [-1.9460129, 53.5121756],
#      [-1.9459601, 53.5122115],
#      [-1.9459826, 53.5122924]]},
#    'properties': {'osid': 'ffac6abc-9924-4fcc-85a3-1a46b135cecf',
#     'toid': 'osgb5000005149533357',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '4bbe3a9f-74b2-4022-8a1f-ab2beaea86ba',
#     'primacy': 1,
#     'gradient': 7.64,
#     'startnode': 'f27e473d-2bdb-44ba-9b10-4672338869de',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'Local',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 185.105,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}},
#   {'id': 'ffc12b3f-0ba4-4a62-bd2b-7d8e1a837d4a',
#    'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-1.9647884, 53.5192251],
#      [-1.9647658, 53.5192475],
#      [-1.9647732, 53.5193419],
#      [-1.9649692, 53.5194273],
#      [-1.9650823, 53.5194454]]},
#    'properties': {'osid': 'ffc12b3f-0ba4-4a62-bd2b-7d8e1a837d4a',
#     'toid': 'osgb5000005148167424',
#     'theme': 'Water',
#     'width': None,
#     'nameid': None,
#     'endnode': '9a30cb5d-6641-4d99-94b7-6729ed1e47f6',
#     'primacy': 1,
#     'gradient': 1.07,
#     'startnode': '23d22374-4416-4dc0-9163-25a9ef3fb315',
#     'watertype': 'Inland',
#     'changetype': 'New',
#     'name1_text': None,
#     'name2_text': None,
#     'permanence': 'Permanent',
#     'catchmentid': '7100',
#     'description': 'Watercourse',
#     'versiondate': '2022-09-02',
#     'catchmentname': 'Mersey',
#     'flowdirection': 'In Direction',
#     'levelofdetail': 'District',
#     'physicallevel': 'Surface Level',
#     'name1_language': None,
#     'name2_language': None,
#     'nametertiaryid': None,
#     'geometry_length': 37.291,
#     'geometry_source': 'Ordnance Survey Line',
#     'namesecondaryid': None,
#     'description_source': 'Ordnance Survey',
#     'nametertiary1_text': None,
#     'nametertiary2_text': None,
#     'geometry_updatedate': '2013-11-26',
#     'namesecondary1_text': None,
#     'namesecondary2_text': None,
#     'physicalcontainment': 'Inapplicable',
#     'capturespecification': 'Moorland',
#     'geometry_evidencedate': '2013-11-26',
#     'description_updatedate': '2013-11-26',
#     'nametertiary1_language': None,
#     'nametertiary2_language': None,
#     'versionavailabletodate': None,
#     'namesecondary1_language': None,
#     'namesecondary2_language': None,
#     'description_evidencedate': '2013-11-26',
#     'versionavailablefromdate': '2022-09-03T00:00:00Z'}}]}

# %% [markdown]
# ## Demos

# %%
everything_test = items_auth_limit_geom_col(
    collections=['lnd-fts-land-3','wtr-fts-water-1','bld-fts-building-3'],
    query_params={'filter-crs':27700},
    request_limit=3,
    verbose=True
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 everything_test = items_auth_limit_geom_col(
#       2     collections=['lnd-fts-land-3','wtr-fts-water-1','bld-fts-building-3'],
#       3     query_params={'filter-crs':27700},
#       4     request_limit=3,
#       5     verbose=True
#       6 )
#
# Cell In[15], line 7, in multiple_collections_extension.<locals>.wrapper(collections, *args, **kwargs)
#       5 results = dict()
#       6 for c in collections:
# ----> 7     json_response = func(c, *args, **kwargs)
#       8     results[c] = json_response
#       9 return results
#
# TypeError: multigeometry_search_extension.<locals>.wrapper() missing 1 required keyword-only argument: 'wkt'
